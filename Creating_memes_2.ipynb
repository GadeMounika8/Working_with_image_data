# %%
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# Open the image
img = Image.open(r"C:\Users\mouni\Downloads\MEME.png")

# Call Draw method to add 2D graphics on the image
DRAW = ImageDraw.Draw(img)
DRAW

text_1 = 'Weekends'
text_2 = '*Employee'
text_3 = 'Weekdays'


font_1 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 60)
font_2 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 60)
font_3 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 60)


DRAW.text((150, 120), text_1, font=font_1, fill=(20, 10, 150))
DRAW.text((600, 30), text_2, font=font_2, fill=(255, 20, 150))
DRAW.text((1000, 150), text_3, font=font_3, fill=(20, 10, 150))


plt.imshow(img)
img.save(r"C:\Users\mouni\Desktop/Meme1.png")

# %%
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# Open the image
img = Image.open(r"C:\Users\mouni\Downloads\IMG_20230707_194327.jpg")

# Call Draw method to add 2D graphics on the image
DRAW = ImageDraw.Draw(img)
DRAW

text_1 = 'Employee'
text_2 = 'Job'
text_3 = 'Skills'


font_1 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_2 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_3 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)


DRAW.text((150, 10), text_1, font=font_1, fill=(255, 255, 0))
DRAW.text((560, 70), text_2, font=font_2, fill=(0, 255, 255))
DRAW.text((340, 140), text_3, font=font_3, fill=(0, 0, 0))


plt.imshow(img)
img.save(r"C:\Users\mouni\Desktop/Meme2.png")
