# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open(r"C:\Users\mouni\Downloads\img_innomatics.PNG")

# %%
plt.imshow(img)

# %%
print(img.size)
# Out:
# (1190, 717)

# %%
w = img.size[0]
print(w)
# Out:
# 1190

# %%
h = img.size[1]
print(h)
# Out:
# 717

# %%
aspect_ratio = w/h
print(aspect_ratio)
# Out:
# 1.6596931659693166

# %%
n_w = 300
n_h = n_w/aspect_ratio

# %%
n_h
# Out:
# 180.7563025210084

# %%
img.resize((n_w, int(n_h)))
# Out:
# <PIL.Image.Image image mode=RGBA size=300x180>

# %%
print(img.size)
# Out:
# (1190, 717)

# %%
img.thumbnail((200))
img.save(r"C:\Users\mouni\Downloads\img_innomatics.PNG")
print(img.size)
plt.inshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16472\965533780.py in <module>
# ----> 1 img.thumbnail((200))
#       2 img.save(r"C:\Users\mouni\Downloads\img_innomatics.PNG")
#       3 print(img.size)
#       4 plt.inshow(img)
#
# C:\anaconda\lib\site-packages\PIL\Image.py in thumbnail(self, size, resample, reducing_gap)
#    2470
#    2471         self.load()
# -> 2472         x, y = map(math.floor, size)
#    2473         if x >= self.width and y >= self.height:
#    2474             return
#
# TypeError: 'int' object is not iterable

# %%
import matplotlib.pyplot as plt
from PIL import Image
img = Image.open(r"C:\Users\mouni\Downloads\meme_1.PNG")
plt.imshow(img)
print(img.size)
w = img.size[0]
print(w)
h = img.size[1]
print(h)
aspect_ratio = w/h
print(aspect_ratio)
n_w = 900
n_h = n_w/aspect_ratio
n_h
img.resize((n_w, int(n_h)))
img.save(r"C:\Users\mouni\Desktop/pict.png")
# Out:
# (1333, 889)
# 1333
# 889
# 1.499437570303712

# %%
import matplotlib.pyplot as plt
from PIL import Image
img = Image.open(r"C:\Users\mouni\Downloads\meme_5.jpg")
plt.imshow(img)
print(img.size)
w = img.size[0]
print(w)
h = img.size[1]
print(h)
aspect_ratio = w/h
print(aspect_ratio)
n_w = 1100
n_h = n_w/aspect_ratio
n_h
img.resize((n_w, int(n_h)))
img.save(r"C:\Users\mouni\Desktop/pict1.png")
# Out:
# (1200, 1200)
# 1200
# 1200
# 1.0

# %%
import matplotlib.pyplot as plt
from PIL import Image
img = Image.open(r"C:\Users\mouni\Downloads\meme_5.jpg")
plt.imshow(img)

# %%
img1 = Image.new(mode = 'RGB', size= (100,100), color = (0,255,0))
plt.imshow(img1)

# %%
from PIL import ImageDraw
draw = ImageDraw.Draw(img1)

# %%
text = 'Hello Mounika'

# %%
draw.text((10,40), text)
plt.imshow(img1)

# %%
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# Open the image
img = Image.open(r"C:\Users\mouni\Downloads\meme_5.jpg")

# Call Draw method to add 2D graphics on the image
DRAW = ImageDraw.Draw(img)
DRAW

text_1 = '*Me'
text_2 = '*Me'
text_3 = """After seeing the Data 
that is given by 
a Client
"""
text_4 = """Seeing the Data 
After the 
completion of 
Data Preparation 
Successfully
"""


font_1 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_2 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_3 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 50)
font_4 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 50)

DRAW.text((150, 30), text_1, font=font_1, fill=(0, 0, 0))
DRAW.text((420, 620), text_2, font=font_2, fill=(0, 0, 0))
DRAW.text((630, 100), text_3, font=font_3, fill=(0, 0, 0))
DRAW.text((630, 800), text_4, font=font_4, fill=(0, 0, 0))

plt.imshow(img)
img.save(r"C:\Users\mouni\Desktop/pict6.png")

# %%
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# Open the image
img = Image.open(r"C:\Users\mouni\Desktop\pict.png")

# Call Draw method to add 2D graphics on the image
DRAW = ImageDraw.Draw(img)
DRAW

text_1 = 'Creating Memes'
text_2 = '*Me'
text_3 = 'Commited with ML'


font_1 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_2 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 60)
font_3 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 38)


DRAW.text((150, 120), text_1, font=font_1, fill=(0, 0, 0))
DRAW.text((600, 30), text_2, font=font_2, fill=(0, 0, 0))
DRAW.text((950, 180), text_3, font=font_3, fill=(0, 0, 0))


plt.imshow(img)
img.save(r"C:\Users\mouni\Desktop/Meme.png")

# %%
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# Open the image
img = Image.open(r"C:\Users\mouni\Downloads\meme_4.PNG")

# Call Draw method to add 2D graphics on the image
DRAW = ImageDraw.Draw(img)
DRAW

text_1 = """HR: We are looking forward to hire 
the Candidates who have 
Real time Experience"""
text_2 = """Fresher(inner feeling): How should i get 
reat time experience without giving a chance?"""
text_3 = "*Fresher Reaction"

font_1 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_2 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_3 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)

DRAW.text((20, 30), text_1, font=font_1, fill=(0, 0, 0))
DRAW.text((20, 200), text_2, font=font_2, fill=(0, 0, 0))
DRAW.text((650, 350), text_3, font=font_3, fill=(0, 0, 0))

plt.imshow(img)
img.save(r"C:\Users\mouni\Desktop/pict2.png")

# %%
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# Open the image
img = Image.open(r"C:\Users\mouni\Downloads\meme_4.PNG")

# Call Draw method to add 2D graphics on the image
DRAW = ImageDraw.Draw(img)
DRAW

text_1 = "HR:" 
text_2 = """We are looking forward to hire the Candidates 
who have Real time Experience."""
text_3 = "Freshers(inner feeling):"""
text_4 = """How should i get 
reat time experience 
without giving a chance?"""
text_5 = "*Freshers Reaction"

font_1 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_2 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_3 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_4 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_5 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)

DRAW.text((20, 30), text_1, font=font_1, fill=(250, 0, 0))
DRAW.text((100, 30), text_2, font=font_2, fill=(0, 0, 0))
DRAW.text((20, 150), text_3, font=font_3, fill=(250, 0, 0))
DRAW.text((510, 150), text_4, font=font_4, fill=(0, 0, 0))
DRAW.text((600, 350), text_5, font=font_5, fill=(0, 0, 0))
plt.imshow(img)
img.save(r"C:\Users\mouni\Desktop/pict4.png")

# %%
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# Open the image
img = Image.open(r"C:\Users\mouni\Downloads\meme_5.jpg")

# Call Draw method to add 2D graphics on the image
DRAW = ImageDraw.Draw(img)
DRAW

text_1 = '*Me'
text_2 = '*Me'
text_3 = """After reading all 
required Skills 
for Data Science 
Roles in Job Description 
before joining in 
Data Science Course
 """
text_4 = """Reading all required 
Skills for Data Science Roles 
in Job Description 
After completion of 
Data Science Course
 """


font_1 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_2 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_3 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)
font_4 = ImageFont.truetype(r"C:\Users\mouni\Downloads\Caprasimo\Caprasimo-Regular.ttf", 40)

DRAW.text((150, 30), text_1, font=font_1, fill=(0, 0, 0))
DRAW.text((420, 620), text_2, font=font_2, fill=(0, 0, 0))
DRAW.text((610, 100), text_3, font=font_3, fill=(10, 90, 210))
DRAW.text((610, 800), text_4, font=font_4, fill=(10, 90, 210))

plt.imshow(img)
img.save(r"C:\Users\mouni\Desktop/pict6.png")
